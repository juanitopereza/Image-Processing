# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
duodeno = plt.imread('imagen_con_ruido_2.png')[:,:,0]

# %%
plt.imshow(duodeno, cmap='gray')

# %%
yeyuno = np.copy(duodeno)
for i in range(1,len(duodeno[:,0])-1):
    for j in range(1,len(duodeno[0])-1):
        yeyuno[i,j] = (duodeno[i-1, j-1] + duodeno[i-1, j] + duodeno[i-1, j+1] +
                      duodeno[i, j-1]   + duodeno[i, j]   + duodeno[i, j+1]   +
                      duodeno[i+1, j-1] + duodeno[i+1, j] + duodeno[i+1, j+1])/9.0

# %%
plt.imshow(yeyuno, cmap='gray')
